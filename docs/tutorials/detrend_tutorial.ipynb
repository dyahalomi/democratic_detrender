# %%
import os
import sys

# Add the project root (two levels up from ~/tutorials/detrend_tutorial) to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
package_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, 'democratic_detrender'))

sys.path.insert(0, project_root)
sys.path.insert(0, package_root)


from democratic_detrend import democratic_detrend as dd
# Out:
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/lightkurve/config/__init__.py:119: UserWarning: The default Lightkurve cache directory, used by download(), etc., has been moved to /Users/daniel/.lightkurve/cache. Please move all the files in the legacy directory /Users/daniel/.lightkurve-cache to the new location and remove the legacy directory. Refer to https://docs.lightkurve.org/reference/config.html#default-cache-directory-migration for more information.
#   warnings.warn(
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
dd('kepler-1513', 
   'Kepler', 
   flux_type='pdc', 
   input_planet_number=2, 
   input_mask_width=1.3,
  )
# Out:
# Exoplanet Archive: Planet Comparison Table
# ------------------------------------------
# NASA Exoplanet Archive planet parameters:
# planet #, [    tic_id      ,    t0 [BJD]    ,  P [days]   , tdur [hrs]]
# planet 1, ['TIC 394177315', 'nan', '841.4', 'nan']
# planet 2, ['TIC 394177315', '2455110.50639', '160.8842', '10.7536']
# no duration information on exoplanet archive for the 1th planet
# assuming 2 hours for 1th planet duration!
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/lightkurve/lightcurve.py:2849: RuntimeWarning: invalid value encountered in remainder
#   in_transit |= np.abs((self.time.value - tt + hp) % per - hp) < 0.5 * dur
# using the following params for the planet we are fitting
# --------------------------------------------------------
# [ t0 [Kepler BJD] , P [days], tdur [hrs]
# [277.50639000022784, 160.8842, 10.7536]
#
# 9 transits (or epochs) in total
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# assuming no pdc problem times
#
#
# detrending now
# --------------
#
#
# detrending via the local method
# local detrending completed in 0.41 seconds
#
# detrending via the polyAM method
# polyAM detrending completed in 2.61 seconds
#
# detrending via the GP method
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='54' class='' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [54/54 00:00<00:00 logp = 3.316e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 33128.59852912107 -> 33157.443617653575
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='65' class='' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [65/65 00:00<00:00 logp = 2.805e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 27963.637297796984 -> 28050.81002210743
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='89' class='' max='89' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [89/89 00:00<00:00 logp = 3.243e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 32047.27154012102 -> 32429.51455687735
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='63' class='' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [63/63 00:00<00:00 logp = 2.236e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 22064.409733127493 -> 22359.49853006862
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='94' class='' max='94' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [94/94 00:00<00:00 logp = 3.373e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 32764.9988450382 -> 33730.04358599593
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='67' class='' max='67' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [67/67 00:00<00:00 logp = 3.388e+04]
#     </div>
# message: Optimization terminated successfully.
# logp: 33319.141909727376 -> 33875.10680487058
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='68' class='' max='68' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [68/68 00:00<00:00 logp = 3.216e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 31545.521950818886 -> 32159.744775127405
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='30' class='' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [30/30 00:00<00:00 logp = 3.314e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 32969.371587429014 -> 33142.70367322335
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='27' class='' max='27' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [27/27 00:00<00:00 logp = 9.529e+03]
#     </div>
# message: Optimization terminated successfully.
# logp: 9462.86210325217 -> 9528.571792590295
# GP detrending completed in 34.7 seconds
#
# detrending via the CoFiAM method
# CoFiAM completed in 46.53 seconds
# detrending methods used: ['local PDCSAP', 'polyAM PDCSAP', 'GP PDCSAP', 'CoFiAM PDCSAP']
#
# starting individual model rejection via DW metric:
# --------------------------------------------------
# DW rejection completed in : 2.824664831161499 seconds
#
#
# starting individual model rejection via binning vs. RMS test:
# --------------------------------------------------
# Execution time: 31.915537118911743 seconds
# polyAM PDCSAP epoch 1 failed dw test
# polyAM PDCSAP epoch 1 failed binning test
# polyAM PDCSAP epoch 2 failed dw test
# polyAM PDCSAP epoch 2 failed binning test
# polyAM PDCSAP epoch 3 failed dw test
# polyAM PDCSAP epoch 3 failed binning test
# polyAM PDCSAP epoch 4 failed dw test
# polyAM PDCSAP epoch 4 failed binning test
# polyAM PDCSAP epoch 5 failed dw test
# polyAM PDCSAP epoch 5 failed binning test
# polyAM PDCSAP epoch 6 failed dw test
# polyAM PDCSAP epoch 6 failed binning test
# polyAM PDCSAP epoch 7 failed dw test
# polyAM PDCSAP epoch 7 failed binning test
# polyAM PDCSAP epoch 8 failed dw test
# polyAM PDCSAP epoch 8 failed binning test
# CoFiAM PDCSAP epoch 1 failed dw test
# CoFiAM PDCSAP epoch 1 failed binning test
# CoFiAM PDCSAP epoch 2 failed dw test
# CoFiAM PDCSAP epoch 2 failed binning test
# CoFiAM PDCSAP epoch 3 failed dw test
# CoFiAM PDCSAP epoch 3 failed binning test
# CoFiAM PDCSAP epoch 4 failed dw test
# CoFiAM PDCSAP epoch 4 failed binning test
# CoFiAM PDCSAP epoch 7 failed binning test
# CoFiAM PDCSAP epoch 8 failed binning test
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/plot.py:245: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(
#              time      yerr   mask  method marginalized  local PDCSAP  \
# 0      274.834317  0.000127  False             0.000014     -0.000009
# 1      274.854750  0.000117  False            -0.000053     -0.000068
# 2      274.875182  0.000109  False            -0.000082     -0.000090
# 3      274.895615  0.000103  False            -0.000039     -0.000040
# 4      274.916048  0.000101  False             0.000058      0.000062
# ...           ...       ...    ...                  ...           ...
# 2132  1567.174937  0.000105  False             0.000046      0.000008
# 2133  1567.195372  0.000105  False             0.000020     -0.000023
# 2134  1567.215806  0.000105  False             0.000036     -0.000013
# 2135  1567.236240  0.000104  False            -0.000042     -0.000098
# 2136  1567.256675  0.000104  False             0.000112      0.000049
#
#       polyAM PDCSAP  GP PDCSAP  CoFiAM PDCSAP
# 0               NaN   0.000038            NaN
# 1               NaN  -0.000038            NaN
# 2               NaN  -0.000074            NaN
# 3               NaN  -0.000037            NaN
# 4               NaN   0.000055            NaN
# ...             ...        ...            ...
# 2132       0.000063   0.000028       0.000068
# 2133       0.000037   0.000002       0.000042
# 2134       0.000054   0.000018       0.000058
# 2135      -0.000024  -0.000060      -0.000021
# 2136       0.000129   0.000095       0.000133
#
# [2137 rows x 8 columns]
