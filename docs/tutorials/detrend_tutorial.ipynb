# %%
import os
import sys

# Add the project root (two levels up from ~/tutorials/detrend_tutorial) to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
package_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, 'democratic_detrender'))

sys.path.insert(0, project_root)
sys.path.insert(0, package_root)


from democratic_detrend import democratic_detrend as dd
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
dd('kepler-1513', 
   'Kepler', 
   flux_type='both', 
   input_planet_number=1, 
   input_mask_width=1.3, 
   input_use_sap_problem_times=True)
# Out:
# Exoplanet Archive: Planet Comparison Table
# ------------------------------------------
# NASA Exoplanet Archive planet parameters:
# planet #, [    tic_id      ,    t0 [BJD]    ,  P [days]   , tdur [hrs]]
# planet 1, ['TIC 394177315', '2455110.50639', '160.8842', '10.7536']
# planet 2, ['TIC 394177315', 'nan', '841.4', 'nan']
# no duration information on exoplanet archive for the 2th planet
# assuming 2 hours for 2th planet duration!
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/lightkurve/lightcurve.py:2693: RuntimeWarning: invalid value encountered in remainder
#   in_transit |= np.abs((self.time.value - tt + hp) % per - hp) < 0.5 * dur
# using the following params for the planet we are fitting
# --------------------------------------------------------
# [ t0 [Kepler BJD] , P [days], tdur [hrs]
# [277.50639000022784, 160.8842, 10.7536]
#
# 9 transits (or epochs) in total
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# using sap problem times for pdc also
# sap_flux problem times for kepler-1513 planet number 1 found
# Exoplanet Archive: Planet Comparison Table
# ------------------------------------------
# NASA Exoplanet Archive planet parameters:
# planet #, [    tic_id      ,    t0 [BJD]    ,  P [days]   , tdur [hrs]]
# planet 1, ['TIC 394177315', '2455110.50639', '160.8842', '10.7536']
# planet 2, ['TIC 394177315', 'nan', '841.4', 'nan']
# no duration information on exoplanet archive for the 2th planet
# assuming 2 hours for 2th planet duration!
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/lightkurve/lightcurve.py:2693: RuntimeWarning: invalid value encountered in remainder
#   in_transit |= np.abs((self.time.value - tt + hp) % per - hp) < 0.5 * dur
# using the following params for the planet we are fitting
# --------------------------------------------------------
# [ t0 [Kepler BJD] , P [days], tdur [hrs]
# [277.50639000022784, 160.8842, 10.7536]
#
# 9 transits (or epochs) in total
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# using sap problem times for pdc also
# pdcsap_flux problem times for kepler-1513 planet number 1 found
#
#
# detrending now
# --------------
#
#
# detrending via the local method
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:62: RankWarning: Polyfit may be poorly conditioned
#   best_model = polyLOC_function(times[~mask], fluxes[~mask], best_degree)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_local.py:48: RankWarning: Polyfit may be poorly conditioned
#   output_function = polyLOC_function(
# local detrending completed in 0.37 seconds
#
# detrending via the polyAM method
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# ...
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/poly_AM.py:74: RankWarning: Polyfit may be poorly conditioned
#   model = polyAM_function(times[~mask], fluxes[~mask], deg)
# polyAM detrending completed in 1.74 seconds
#
# detrending via the GP method
# GP failed for the 1th epoch: failed to find parameter estimates:
# The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='65' class='' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [65/65 00:00<00:00 logp = 2.805e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 27963.637297796984 -> 28050.81002210743
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='64' class='' max='64' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [64/64 00:00<00:00 logp = 1.098e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10882.518389099776 -> 10980.24777572253
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='87' class='' max='87' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [87/87 00:00<00:00 logp = 2.240e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 22098.149095418026 -> 22397.823944387146
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='94' class='' max='94' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [94/94 00:00<00:00 logp = 3.373e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 32764.9988450382 -> 33730.04358599593
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='60' class='' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60/60 00:00<00:00 logp = 9.287e+03]
#     </div>
# message: Optimization terminated successfully.
# logp: 9233.265057490642 -> 9286.975475222238
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='60' class='' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60/60 00:00<00:00 logp = 3.065e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 30057.20638267784 -> 30651.555417775904
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='30' class='' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [30/30 00:00<00:00 logp = 3.314e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 32969.371587429014 -> 33142.70367322335
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='27' class='' max='27' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [27/27 00:00<00:00 logp = 9.529e+03]
#     </div>
# message: Optimization terminated successfully.
# logp: 9462.86210325217 -> 9528.571792590295
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1119: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# GP detrending completed in 10.79 seconds
#
# detrending via the CoFiAM method
# CoFiAM completed in 33.81 seconds
#
#
# pdc length in:  2056
# sap length in:  2057
# ---
# pdc length out:  2057
# sap length out:  2057
#
#
#
# detrending methods used: ['local SAP', 'local PDCSAP', 'polyAM SAP', 'polyAM PDCSAP', 'GP SAP', 'GP PDCSAP', 'CoFiAM SAP', 'CoFiAM PDCSAP']
#
# starting individual model rejection via DW metric:
# --------------------------------------------------
# DW rejection completed in : 0.37536001205444336 seconds
#
#
# starting individual model rejection via binning vs. RMS test:
# --------------------------------------------------
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1670: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/method_rejection_functions_binning.py:136: RuntimeWarning: Mean of empty slice
#   binned_means = np.nanmean(bins, axis=1)
# /Users/daniel/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1119: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# Execution time: 0.4416630268096924 seconds
# local SAP epoch 1 failed binning test
# local SAP epoch 6 failed binning test
# local SAP epoch 7 failed binning test
# local SAP epoch 8 failed dw test
# local SAP epoch 8 failed binning test
# local PDCSAP epoch 1 failed binning test
# local PDCSAP epoch 2 failed dw test
# local PDCSAP epoch 4 failed dw test
# local PDCSAP epoch 4 failed binning test
# local PDCSAP epoch 6 failed binning test
# local PDCSAP epoch 7 failed binning test
# polyAM SAP epoch 1 failed binning test
# polyAM SAP epoch 3 failed dw test
# polyAM SAP epoch 3 failed binning test
# polyAM SAP epoch 4 failed binning test
# polyAM SAP epoch 5 failed binning test
# polyAM SAP epoch 6 failed dw test
# polyAM SAP epoch 6 failed binning test
# polyAM SAP epoch 7 failed dw test
# polyAM SAP epoch 7 failed binning test
# polyAM SAP epoch 8 failed dw test
# polyAM SAP epoch 8 failed binning test
# polyAM SAP epoch 9 failed binning test
# polyAM PDCSAP epoch 1 failed dw test
# polyAM PDCSAP epoch 1 failed binning test
# polyAM PDCSAP epoch 2 failed dw test
# polyAM PDCSAP epoch 2 failed binning test
# polyAM PDCSAP epoch 3 failed dw test
# polyAM PDCSAP epoch 3 failed binning test
# polyAM PDCSAP epoch 4 failed dw test
# polyAM PDCSAP epoch 4 failed binning test
# polyAM PDCSAP epoch 5 failed binning test
# polyAM PDCSAP epoch 6 failed dw test
# polyAM PDCSAP epoch 6 failed binning test
# polyAM PDCSAP epoch 7 failed dw test
# polyAM PDCSAP epoch 7 failed binning test
# polyAM PDCSAP epoch 8 failed dw test
# polyAM PDCSAP epoch 8 failed binning test
# polyAM PDCSAP epoch 9 failed binning test
# GP PDCSAP epoch 1 failed binning test
# CoFiAM SAP epoch 3 failed binning test
# CoFiAM SAP epoch 5 failed binning test
# CoFiAM SAP epoch 7 failed binning test
# CoFiAM SAP epoch 8 failed dw test
# CoFiAM SAP epoch 8 failed binning test
# CoFiAM PDCSAP epoch 2 failed dw test
# CoFiAM PDCSAP epoch 2 failed binning test
# CoFiAM PDCSAP epoch 4 failed dw test
# CoFiAM PDCSAP epoch 4 failed binning test
# CoFiAM PDCSAP epoch 7 failed binning test
# CoFiAM PDCSAP epoch 8 failed binning test
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/plot.py:245: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(
#              time      yerr   mask  method marginalized  local SAP  \
# 0      274.834317  0.000098  False             0.000023        NaN
# 1      274.854750  0.000105  False            -0.000009        NaN
# 2      274.875182  0.000108  False            -0.000036        NaN
# 3      274.895615  0.000103  False            -0.000004        NaN
# 4      274.916048  0.000117  False             0.000109        NaN
# ...           ...       ...    ...                  ...        ...
# 2052  1567.174937  0.000106  False             0.000047   0.000069
# 2053  1567.195372  0.000105  False            -0.000004   0.000008
# 2054  1567.215806  0.000103  False             0.000023   0.000046
# 2055  1567.236240  0.000105  False            -0.000046  -0.000022
# 2056  1567.256675  0.000107  False             0.000088   0.000103
#
#       local PDCSAP  polyAM SAP  polyAM PDCSAP    GP SAP  GP PDCSAP  \
# 0              NaN         NaN            NaN  0.000016        NaN
# 1              NaN         NaN            NaN -0.000009        NaN
# 2              NaN         NaN            NaN -0.000036        NaN
# 3              NaN         NaN            NaN -0.000004        NaN
# 4              NaN         NaN            NaN  0.000110        NaN
# ...            ...         ...            ...       ...        ...
# 2052      0.000008         NaN            NaN  0.000044   0.000028
# 2053     -0.000023         NaN            NaN -0.000018   0.000002
# 2054     -0.000013         NaN            NaN  0.000020   0.000018
# 2055     -0.000098         NaN            NaN -0.000049  -0.000060
# 2056      0.000049         NaN            NaN  0.000077   0.000095
#
#       CoFiAM SAP  CoFiAM PDCSAP
# 0       0.000023       0.000036
# 1      -0.000004      -0.000038
# 2      -0.000033      -0.000072
# 3      -0.000003      -0.000033
# 4       0.000109       0.000060
# ...          ...            ...
# 2052    0.000051       0.000068
# 2053   -0.000011       0.000042
# 2054    0.000027       0.000058
# 2055   -0.000043      -0.000021
# 2056    0.000082       0.000133
#
# [2057 rows x 12 columns]
