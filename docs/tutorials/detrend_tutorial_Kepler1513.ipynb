# %%
import os
import sys

# Add the project root (two levels up from ~/tutorials/detrend_tutorial) to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
package_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, 'democratic_detrender'))

sys.path.insert(0, project_root)
sys.path.insert(0, package_root)


from democratic_detrend import democratic_detrend as dd
# Out:
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/lightkurve/config/__init__.py:119: UserWarning: The default Lightkurve cache directory, used by download(), etc., has been moved to /Users/daniel/.lightkurve/cache. Please move all the files in the legacy directory /Users/daniel/.lightkurve-cache to the new location and remove the legacy directory. Refer to https://docs.lightkurve.org/reference/config.html#default-cache-directory-migration for more information.
#   warnings.warn(
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
dd('kepler-1513', 'Kepler', flux_type='both', input_use_sap_problem_times=True)
# Out:
# Exoplanet Archive: Planet Comparison Table
# ------------------------------------------
# NASA Exoplanet Archive planet parameters:
# planet #, [    tic_id      ,    t0 [BJD]    ,  P [days]   , tdur [hrs]]
# planet 1, ['TIC 394177315', '2455110.50639', '160.8842', '10.7536']
# planet 2, ['TIC 394177315', 'nan', '841.4', 'nan']
# no duration information on exoplanet archive for the 2th planet
# assuming 2 hours for 2th planet duration!
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/lightkurve/lightcurve.py:2849: RuntimeWarning: invalid value encountered in remainder
#   in_transit |= np.abs((self.time.value - tt + hp) % per - hp) < 0.5 * dur
# using the following params for the planet we are fitting
# --------------------------------------------------------
# [ t0 [Kepler BJD] , P [days], tdur [hrs]
# [277.50639000022784, 160.8842, 10.7536]
#
# 9 transits (or epochs) in total
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# using sap problem times for pdc also
# sap_flux problem times for kepler-1513 planet number 1 found
# Exoplanet Archive: Planet Comparison Table
# ------------------------------------------
# NASA Exoplanet Archive planet parameters:
# planet #, [    tic_id      ,    t0 [BJD]    ,  P [days]   , tdur [hrs]]
# planet 1, ['TIC 394177315', '2455110.50639', '160.8842', '10.7536']
# planet 2, ['TIC 394177315', 'nan', '841.4', 'nan']
# no duration information on exoplanet archive for the 2th planet
# assuming 2 hours for 2th planet duration!
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/lightkurve/lightcurve.py:2849: RuntimeWarning: invalid value encountered in remainder
#   in_transit |= np.abs((self.time.value - tt + hp) % per - hp) < 0.5 * dur
# using the following params for the planet we are fitting
# --------------------------------------------------------
# [ t0 [Kepler BJD] , P [days], tdur [hrs]
# [277.50639000022784, 160.8842, 10.7536]
#
# 9 transits (or epochs) in total
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# using sap problem times for pdc also
# pdcsap_flux problem times for kepler-1513 planet number 1 found
#
#
# detrending now
# --------------
#
#
# detrending via the local method
# local detrending completed in 0.35 seconds
#
# detrending via the polyAM method
# polyAM detrending completed in 1.67 seconds
#
# detrending via the GP method
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='69' class='' max='69' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [69/69 00:00<00:00 logp = 1.065e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 10107.391757526604 -> 10648.254453487889
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='61' class='' max='61' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [61/61 00:00<00:00 logp = 2.854e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 27446.846425078256 -> 28537.438196021132
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='75' class='' max='75' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [75/75 00:00<00:00 logp = 1.094e+04]
#     </div>
# message: Optimization terminated successfully.
# logp: 10427.935560679349 -> 10944.324656403409
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='31' class='' max='31' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [31/31 00:00<00:00 logp = 2.346e+04]
#     </div>
# message: Optimization terminated successfully.
# logp: 21922.930958560853 -> 23457.917417768953
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='74' class='' max='74' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [74/74 00:00<00:00 logp = 3.354e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 31375.07616972332 -> 33536.4897121444
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='104' class='' max='104' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [104/104 00:00<00:00 logp = 9.292e+03]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 8476.067546449038 -> 9291.61615747967
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44' class='' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44/44 00:00<00:00 logp = 3.058e+04]
#     </div>
# message: Optimization terminated successfully.
# logp: 29334.440034136165 -> 30584.263402508062
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='77' class='' max='77' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [77/77 00:00<00:00 logp = 3.320e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 31485.760099514668 -> 33204.29267570419
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='143' class='' max='143' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [143/143 00:00<00:00 logp = 9.560e+03]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 9476.483510282318 -> 9560.444851275162
# GP detrending completed in 33.04 seconds
#
# detrending via the CoFiAM method
# CoFiAM completed in 33.96 seconds
#
# detrending via the local method
# local detrending completed in 0.34 seconds
#
# detrending via the polyAM method
# polyAM detrending completed in 1.63 seconds
#
# detrending via the GP method
# GP failed for the 0th epoch: failed to find parameter estimates:
# The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='65' class='' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [65/65 00:00<00:00 logp = 2.808e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 27991.986551118815 -> 28078.55794237985
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='22' class='' max='22' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [22/22 00:00<00:00 logp = 1.100e+04]
#     </div>
# message: Optimization terminated successfully.
# logp: 10898.402471417887 -> 10996.5505036374
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='118' class='' max='118' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [118/118 00:00<00:00 logp = 2.239e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 22095.92118146195 -> 22390.255556524047
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='72' class='' max='72' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [72/72 00:00<00:00 logp = 3.376e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 32800.419748223176 -> 33761.58111404778
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='112' class='' max='112' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [112/112 00:00<00:00 logp = 9.311e+03]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 9257.528216581348 -> 9311.497750073748
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='31' class='' max='31' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [31/31 00:00<00:00 logp = 3.069e+04]
#     </div>
# message: Optimization terminated successfully.
# logp: 30097.291704415555 -> 30692.265058279936
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='139' class='' max='139' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [139/139 00:00<00:00 logp = 3.317e+04]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 32998.81908448472 -> 33173.29671435471
# optimizing logp for variables: [sigma_gp, mean, rho_gp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='116' class='' max='116' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [116/116 00:00<00:00 logp = 9.560e+03]
#     </div>
# message: Desired error not necessarily achieved due to precision loss.
# logp: 9493.547393734985 -> 9559.649718966586
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# GP detrending completed in 10.23 seconds
#
# detrending via the CoFiAM method
# CoFiAM completed in 33.89 seconds
#
#
# pdc length in:  2056
# sap length in:  2057
# ---
# pdc length out:  2057
# sap length out:  2057
#
#
#
#
# starting individual model rejection via DW metric:
# --------------------------------------------------
# DW rejection completed in : 6.133865833282471 seconds
# starting individual model rejection via binning vs. RMS test:
# --------------------------------------------------
# /Users/daniel/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1664: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/method_rejection_functions_binning.py:135: RuntimeWarning: Mean of empty slice
#   binned[i] = np.nanmean(y[b*i+1:(i+1)*b])
# /Users/daniel/Desktop/dd_github/democratic_detrender/democratic_detrender/method_rejection_functions_binning.py:146: RuntimeWarning: Mean of empty slice
#   beta = np.nanmean(np.array(beta_n))
# Execution time: 102.87317395210266 seconds
# 0
# [1.4528364388280985, 1.441140204030414, 1.6743279051182673, 1.732221815133929, 0.7495575687779539, nan, 1.2235679398348465, 0.9736678168300539]
#
# 1
# [1.006238553474923, 1.3868974413399882, 1.0581888586538988, 1.7814443008574457, 0.7790846976172617, 0.6165563821278025, 1.0248380105833894, 1.5044408013474537]
#
# 2
# [1.0923953558309594, 1.190018775330083, 2.1113625022470837, 1.803213879056471, 1.004349161899452, 1.0433944209333337, 1.4468457576581855, 1.2876700337845541]
#
# 3
# [1.330681389947875, 1.5172793761523669, 1.7994284156829259, 2.0154077041818463, 0.9303615546591371, 0.5614222466712452, 1.203085393887519, 1.5262285796422366]
#
# 4
# [1.299131245894847, 1.2346848321091994, 1.7840964559466506, 1.4982949400175924, 0.5980974605518249, 0.6698250886225838, 1.5900830914857287, 1.2857301456559218]
#
# 5
# [1.4433548403120506, 1.4150350760898873, 2.3621725868595025, 2.128003736929484, 0.7487421824864345, 0.7155524692987707, 0.9481516667253342, 0.9733914801672667]
#
# 6
# [1.615356723739998, 1.6090012910388665, 2.5760844090569854, 2.42785361889916, 0.892258350858544, 0.9246751983914561, 1.7136914792266318, 1.7156661447664403]
#
# 7
# [1.8639462258792516, 1.1981172922717283, 2.5107773437837313, 2.714590405548678, 0.8161282862628843, 0.7839985580959171, 2.210182739960606, 1.4266105372923894]
#
# 8
# [1.2198586868847483, 1.1486777992130803, 1.4628341565652492, 1.5658043069362804, 0.752748777888939, 0.730236853829386, 1.330183988783247, 1.2090226066656864]
# local SAP epoch 1 failed binning test
# local SAP epoch 3 failed binning test
# local SAP epoch 5 failed binning test
# local SAP epoch 6 failed binning test
# local SAP epoch 7 failed binning test
# local SAP epoch 8 failed dw test
# local SAP epoch 8 failed binning test
# local SAP epoch 9 failed binning test
# local PDCSAP epoch 1 failed dw test
# local PDCSAP epoch 1 failed binning test
# local PDCSAP epoch 2 failed dw test
# local PDCSAP epoch 2 failed binning test
# local PDCSAP epoch 3 failed binning test
# local PDCSAP epoch 4 failed dw test
# local PDCSAP epoch 4 failed binning test
# local PDCSAP epoch 6 failed binning test
# local PDCSAP epoch 7 failed binning test
# local PDCSAP epoch 8 failed binning test
# polyAM SAP epoch 1 failed binning test
# polyAM SAP epoch 3 failed dw test
# polyAM SAP epoch 3 failed binning test
# polyAM SAP epoch 4 failed binning test
# polyAM SAP epoch 5 failed binning test
# polyAM SAP epoch 6 failed dw test
# polyAM SAP epoch 6 failed binning test
# polyAM SAP epoch 7 failed dw test
# polyAM SAP epoch 7 failed binning test
# polyAM SAP epoch 8 failed dw test
# polyAM SAP epoch 8 failed binning test
# polyAM SAP epoch 9 failed binning test
# polyAM PDCSAP epoch 1 failed dw test
# polyAM PDCSAP epoch 1 failed binning test
# polyAM PDCSAP epoch 2 failed dw test
# polyAM PDCSAP epoch 2 failed binning test
# polyAM PDCSAP epoch 3 failed dw test
# polyAM PDCSAP epoch 3 failed binning test
# polyAM PDCSAP epoch 4 failed dw test
# polyAM PDCSAP epoch 4 failed binning test
# polyAM PDCSAP epoch 5 failed binning test
# polyAM PDCSAP epoch 6 failed dw test
# polyAM PDCSAP epoch 6 failed binning test
# polyAM PDCSAP epoch 7 failed dw test
# polyAM PDCSAP epoch 7 failed binning test
# polyAM PDCSAP epoch 8 failed dw test
# polyAM PDCSAP epoch 8 failed binning test
# polyAM PDCSAP epoch 9 failed binning test
# GP PDCSAP epoch 1 failed binning test
# CoFiAM SAP epoch 1 failed binning test
# CoFiAM SAP epoch 3 failed binning test
# CoFiAM SAP epoch 5 failed binning test
# CoFiAM SAP epoch 7 failed binning test
# CoFiAM SAP epoch 8 failed dw test
# CoFiAM SAP epoch 8 failed binning test
# CoFiAM SAP epoch 9 failed binning test
# CoFiAM PDCSAP epoch 2 failed dw test
# CoFiAM PDCSAP epoch 2 failed binning test
# CoFiAM PDCSAP epoch 3 failed binning test
# CoFiAM PDCSAP epoch 4 failed dw test
# CoFiAM PDCSAP epoch 4 failed binning test
# CoFiAM PDCSAP epoch 5 failed binning test
# CoFiAM PDCSAP epoch 7 failed binning test
# CoFiAM PDCSAP epoch 8 failed binning test
# CoFiAM PDCSAP epoch 9 failed binning test
#              time      yerr   mask  method marginalized  local SAP  \
# 0      274.834317  0.000102  False             0.000026        NaN
# 1      274.854750  0.000106  False            -0.000023        NaN
# 2      274.875182  0.000111  False            -0.000054        NaN
# 3      274.895615  0.000106  False            -0.000018        NaN
# 4      274.916048  0.000125  False             0.000086        NaN
# ...           ...       ...    ...                  ...        ...
# 2052  1567.174937  0.000103  False             0.000028        NaN
# 2053  1567.195372  0.000104  False            -0.000017        NaN
# 2054  1567.215806  0.000101  False             0.000019        NaN
# 2055  1567.236240  0.000102  False            -0.000059        NaN
# 2056  1567.256675  0.000108  False             0.000077        NaN
#
#       local PDCSAP  polyAM SAP  polyAM PDCSAP    GP SAP  GP PDCSAP  \
# 0              NaN         NaN            NaN  0.000016        NaN
# 1              NaN         NaN            NaN -0.000009        NaN
# 2              NaN         NaN            NaN -0.000036        NaN
# 3              NaN         NaN            NaN -0.000004        NaN
# 4              NaN         NaN            NaN  0.000110        NaN
# ...            ...         ...            ...       ...        ...
# 2052      0.000008         NaN            NaN  0.000044   0.000028
# 2053     -0.000024         NaN            NaN -0.000017   0.000002
# 2054     -0.000013         NaN            NaN  0.000020   0.000019
# 2055     -0.000098         NaN            NaN -0.000049  -0.000059
# 2056      0.000049         NaN            NaN  0.000077   0.000095
#
#       CoFiAM SAP  CoFiAM PDCSAP
# 0            NaN       0.000036
# 1            NaN      -0.000037
# 2            NaN      -0.000072
# 3            NaN      -0.000033
# 4            NaN       0.000061
# ...          ...            ...
# 2052         NaN            NaN
# 2053         NaN            NaN
# 2054         NaN            NaN
# 2055         NaN            NaN
# 2056         NaN            NaN
#
# [2057 rows x 12 columns]
